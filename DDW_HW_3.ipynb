# %%
import nltk
import wikipedia
from collections import Counter

# %% [markdown]
# ## Loading data

# %%
path = './bbc/entertainment/'
files = [str(x+1).zfill(3)+'.txt' for x in range(100)]

# %%
text = ''
for order in files:
    with open(path+order, 'r') as file:
        text += (file.read())

# %%
text
# Out:
# 'Gallery unveils interactive tree\n\nA Christmas tree that can receive text messages has been unveiled at London\'s Tate Britain art gallery.\n\nThe spruce has an antenna which can receive Bluetooth texts sent by visitors to the Tate. The messages will be "unwrapped" by sculptor Richard Wentworth, who is responsible for decorating the tree with broken plates and light bulbs. It is the 17th year that the gallery has invited an artist to dress their Christmas tree. Artists who have decorated the Tate tree in previous years include Tracey Emin in 2002.\n\nThe plain green Norway spruce is displayed in the gallery\'s foyer. Its light bulb adornments are dimmed, ordinary domestic ones joined together with string. The plates decorating the branches will be auctioned off for the children\'s charity ArtWorks. Wentworth worked as an assistant to sculptor Henry Moore in the late 1960s. His reputation as a sculptor grew in the 1980s, while he has been one of the most influential teachers during the last two decades. Wentworth is also known for his photography of mundane, everyday subjects such as a cigarette packet jammed under the wonky leg of a table.\nJarre joins fairytale celebration\n\nFrench musician Jean-Michel Jarre is to perform at a concert in Copenhagen to mark the bicentennial of the birth of writer Hans Christian Andersen.\n\nDenmark is holding a three-day celebration of the life of the fairy-tale author, with a concert at Parken stadium on 2 April. Other stars are expected to join the line-up in the coming months, and the Danish royal family will attend. "Christian Andersen\'s fairy tales are timeless and universal," said Jarre. "For all of us, at any age there is always - beyond the pure enjoyment of the tale - a message to learn." There are year-long celebrations planned across the world to celebrate Andersen and his work, which includes The Emperor\'s New Clothes and The Little Mermaid. Denmark\'s Crown Prince Frederik and Crown Princess Mary visited New York on Monday to help promote the festivities. The pair were at a Manhattan library to honour US literary critic Harold Bloom "the international icon we thought we knew so well".\n\n"Bloom recognizes the darker aspects of Andersen\'s authorship," Prince Frederik said. Bloom is to be formally presented with the Hans Christian Andersen Award this spring in Anderson\'s hometown of Odense. The royal couple also visited the Hans Christian Anderson School complex, where Queen Mary read The Ugly Duckling to the young audience. Later at a gala dinner, Danish supermodel Helena Christensen was named a Hans Christian Andersen ambassador. Other ambassadors include actors Harvey Keitel and Sir Roger Moore, athlete Cathy Freeman and Brazilian soccer legend Pele.\nMusical treatment for Capra film\n\nThe classic film It\'s A Wonderful Life is to be turned into a musical by the producer of the controversial hit show Jerry Springer - The Opera.\n\nFrank Capra\'s 1946 movie starring James Stewart, is being turned into a £7m musical by producer Jon Thoday. He is working with Steve Brown, who wrote the award-winning musical Spend Spend Spend. A spokeswoman said the plans were in the "very early stages", with no cast, opening date or theatre announced.\n\nA series of workshops have been held in London, and on Wednesday a cast of singers unveiled the musical to a select group of potential investors. Mr Thoday said the idea of turning the film into a musical had been an ambition of his for almost 20 years. It\'s a Wonderful Life was based on a short story, The Greatest Gift, by Philip van Doren Stern. Mr Thoday managed to buy the rights to the story from Van Doren Stern\'s family in 1999, following Mr Brown\'s success with Spend Spend Spend. He later secured the film rights from Paramount, enabling them to use the title It\'s A Wonderful Life.\nRichard and Judy choose top books\n\nThe 10 authors shortlisted for a Richard and Judy book award in 2005 are hoping for a boost in sales following the  ...

# %% [markdown]
# ## Data preprocessing

# %%
tokens = nltk.word_tokenize(text)
tagged = nltk.pos_tag(tokens)

# %%
sentences = nltk.sent_tokenize(text)

# %%
len(sentences)
# Out:
# 1427

# %%
tagged
# Out:
# [('Gallery', 'NNP'),
#  ('unveils', 'JJ'),
#  ('interactive', 'JJ'),
#  ('tree', 'NN'),
#  ('A', 'NNP'),
#  ('Christmas', 'NNP'),
#  ('tree', 'NN'),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('receive', 'VB'),
#  ('text', 'NN'),
#  ('messages', 'NNS'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('unveiled', 'VBN'),
#  ('at', 'IN'),
#  ('London', 'NNP'),
#  ("'s", 'POS'),
#  ('Tate', 'NNP'),
#  ('Britain', 'NNP'),
#  ('art', 'JJ'),
#  ('gallery', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('spruce', 'NN'),
#  ('has', 'VBZ'),
#  ('an', 'DT'),
#  ('antenna', 'NN'),
#  ('which', 'WDT'),
#  ('can', 'MD'),
#  ('receive', 'VB'),
#  ('Bluetooth', 'NNP'),
#  ('texts', 'FW'),
#  ('sent', 'VBN'),
#  ('by', 'IN'),
#  ('visitors', 'NNS'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('Tate', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('messages', 'NNS'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('``', '``'),
#  ('unwrapped', 'JJ'),
#  ("''", "''"),
#  ('by', 'IN'),
#  ('sculptor', 'NN'),
#  ('Richard', 'NNP'),
#  ('Wentworth', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('is', 'VBZ'),
#  ('responsible', 'JJ'),
#  ('for', 'IN'),
#  ('decorating', 'VBG'),
#  ('the', 'DT'),
#  ('tree', 'NN'),
#  ('with', 'IN'),
#  ('broken', 'JJ'),
#  ('plates', 'NNS'),
#  ('and', 'CC'),
#  ('light', 'NN'),
#  ('bulbs', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('17th', 'JJ'),
#  ('year', 'NN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('gallery', 'NN'),
#  ('has', 'VBZ'),
#  ('invited', 'VBN'),
#  ('an', 'DT'),
#  ('artist', 'NN'),
#  ('to', 'TO'),
#  ('dress', 'VB'),
#  ('their', 'PRP$'),
#  ('Christmas', 'NNP'),
#  ('tree', 'NN'),
#  ('.', '.'),
#  ('Artists', 'NNS'),
#  ('who', 'WP'),
#  ('have', 'VBP'),
#  ('decorated', 'VBN'),
#  ('the', 'DT'),
#  ('Tate', 'NNP'),
#  ('tree', 'NN'),
#  ('in', 'IN'),
#  ('previous', 'JJ'),
#  ('years', 'NNS'),
#  ('include', 'VBP'),
#  ('Tracey', 'NNP'),
#  ('Emin', 'NNP'),
#  ('in', 'IN'),
#  ('2002', 'CD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('plain', 'NN'),
#  ('green', 'JJ'),
#  ('Norway', 'NNP'),
#  ('spruce', 'NN'),
#  ('is', 'VBZ'),
#  ('displayed', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('gallery', 'NN'),
#  ("'s", 'POS'),
#  ('foyer', 'NN'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('light', 'JJ'),
#  ('bulb', 'NN'),
#  ('adornments', 'NNS'),
#  ('are', 'VBP'),
#  ('dimmed', 'VBN'),
#  (',', ','),
#  ('ordinary', 'JJ'),
#  ('domestic', 'JJ'),
#  ('ones', 'NNS'),
#  ('joined', 'VBD'),
#  ('together', 'RB'),
#  ('with', 'IN'),
#  ('string', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('plates', 'NNS'),
#  ('decorating', 'VBG'),
#  ('the', 'DT'),
#  ('branches', 'NNS'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('auctioned', 'VBN'),
#  ('off', 'RP'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('children', 'NNS'),
#  ("'s", 'POS'),
#  ('charity', 'NN'),
#  ('ArtWorks', 'NNP'),
#  ('.', '.'),
#  ('Wentworth', 'NNP'),
#  ('worked', 'VBD'),
#  ('as', 'IN'),
#  ('an', 'DT'),
#  ('assistant', 'NN'),
#  ('to', 'TO'),
#  ('sculptor', 'VB'),
#  ('Henry', 'NNP'),
#  ('Moore', 'NNP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('late', 'JJ'),
#  ('1960s', 'NNS'),
#  ('.', '.'),
#  ('His', 'PRP$'),
#  ('reputation', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('sculptor', 'NN'),
#  ('grew', 'VBD'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('1980s', 'CD'),
#  (',', ','),
#  ('while', 'IN'),
#  ('he', 'PRP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('influential', 'JJ'),
#  ('teachers', 'NNS'),
#  ('during', 'IN'),
#  ('the', 'DT'),
#  ('last', 'JJ'),
#  ('two', 'CD'),
#  ('decades', 'NNS'),
#  ('.', '.'),
#  ('Wentworth', 'NNP'),
#  ('is', 'VBZ'),
#  ('also', 'RB'),
#  ('known', 'VBN'),
#  ('for', 'IN'),
#  ('his', 'PRP$'),
#  ('photography', 'NN'),
#  ('of', 'IN'),
#  ('mundane', 'NN'),
#  (',', ','),
#  ('everyday', 'JJ'),
#  ('subjects', 'NNS'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('cigarette', 'NN'),
#  ('packet', 'NN'),
#  ('jammed', 'VBD'),
#  ('under', 'IN'),
#  ('the', 'DT'),
#  ('wonky', 'JJ'),
#  ('leg', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('table', 'NN'),
#  ('.', '.'),
#  ('Jarre', 'NNP'),
#  ('joins', 'VBZ'),
#  ('fairytale', 'JJ'),
#  ('celebration', 'NN'),
#  ('French', 'JJ'),
#  ('musician', 'JJ'),
#  ('Jean-Michel', 'NNP'),
#  ('Jarre', 'NNP'),
#  ('is', 'VBZ'),
#  ('to', 'TO'),
#  ('perform', 'VB'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('concert', 'NN'),
#  ('in', 'IN'),
#  ('Copenhagen', 'NNP'),
#  ('to', 'TO'),
#  ('mark', 'VB'),
#  ('the', 'DT'),
#  ('bicentennial', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('birth', 'NN'),
#  ('of', 'IN'),
#  ('writer', 'NN'),
#  ('Hans', 'NNP'),
#  ('Christian', 'NNP'),
#  ('Andersen', 'NNP'),
#  ('.', '.'),
#  ('Denmark', 'NNP'),
#  ('is', 'VBZ'),
#  ('holding', 'VBG'),
#  ('a', 'DT'),
#  ('three-day', 'JJ'),
#  ('celebration', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('life', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('fairy-tale', 'JJ'),
#  ('author', 'NN'),
#  (',', ','),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('concert', 'NN'),
#  ('at', 'IN'),
#  ('Parken', 'NNP'),
#  ('stadium', 'NN'),
#  ('on', 'IN'),
#  ('2', 'CD'),
#  ('April', 'NNP'),
#  ('.', '.'),
#  ('Other', 'JJ'),
#  ('stars', 'NNS'),
#  ('are', 'VBP'),
#  ('expected', 'VBN'),
#  ('to', 'TO'),
#  ('join', 'VB'),
#  ('the', 'DT'),
#  ('line-up', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('coming', 'JJ'),
#  ('months', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Danish', 'NNP'),
#  ('royal', 'VBP'),
#  ('family', 'NN'),
#  ('will', 'MD'),
#  ('attend', 'VB'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Christian', 'JJ'),
#  ('Andersen', 'NNP'),
#  ("'s", 'POS'),
#  ('fairy', 'NN'),
#  ('tales', 'NNS'),
#  ('are', 'VBP'),
#  ('timeless', 'JJ'),
#  ('and', 'CC'),
#  ('universal', 'JJ'),
#  (',', ','),
#  ("''", "''"),
#  ('said', 'VBD'),
#  ('Jarre', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('For', 'IN'),
#  ('all', 'DT'),
#  ('of', 'IN'),
#  ('us', 'PRP'),
#  (',', ','),
#  ('at', 'IN'),
#  ('any', 'DT'),
#  ('age', 'NN'),
#  ('there', 'EX'),
#  ('is', 'VBZ'),
#  ('always', 'RB'),
#  ('-', ':'),
#  ('beyond', 'IN'),
#  ('the', 'DT'),
#  ('pure', 'JJ'),
#  ('enjoyment', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('tale', 'NN'),
#  ('-', ':'),
#  ('a', 'DT'),
#  ('message', 'NN'),
#  ('to', 'TO'),
#  ('learn', 'VB'),
#  ('.', '.'),
#  ("''", "''"),
#  ('There', 'EX'),
#  ('are', 'VBP'),
#  ('year-long', 'JJ'),
#  ('celebrations', 'NNS'),
#  ('planned', 'VBN'),
#  ('across', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('to', 'TO'),
#  ('celebrate', 'VB'),
#  ('Andersen', 'NNP'),
#  ('and', 'CC'),
#  ('his', 'PRP$'),
#  ('work', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('includes', 'VBZ'),
#  ('The', 'DT'),
#  ('Emperor', 'NNP'),
#  ("'s", 'POS'),
#  ('New', 'NNP'),
#  ('Clothes', 'NNP'),
#  ('and', 'CC'),
#  ('The', 'DT'),
#  ('Little', 'NNP'),
#  ('Mermaid', 'NNP'),
#  ('.', '.'),
#  ('Denmark', 'NNP'),
#  ("'s", 'POS'),
#  ('Crown', 'NNP'),
#  ('Prince', 'NNP'),
#  ('Frederik', 'NNP'),
#  ('and', 'CC'),
#  ('Crown', 'NNP'),
#  ('Princess', 'NNP'),
#  ('Mary', 'NNP'),
#  ('visited', 'VBD'),
#  ('New', 'NNP'),
#  ('York', 'NNP'),
#  ('on', 'IN'),
#  ('Monday', 'NNP'),
#  ('to', 'TO'),
#  ('help', 'VB'),
#  ('promote', 'VB'),
#  ('the', 'DT'),
#  ('festivities', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('pair', 'NN'),
#  ('were', 'VBD'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('Manhattan', 'NNP'),
#  ('library', 'NN'),
#  ('to', 'TO'),
#  ('honour', 'VB'),
#  ('US', 'NNP'),
#  ('literary', 'JJ'),
#  ('critic', 'NN'),
#  ('Harold', 'NNP'),
#  ('Bloom', 'NNP'),
#  ('``', '``'),
#  ('the', 'DT'),
#  ('international', 'JJ'),
#  ('icon', 'NN'),
#  ('we', 'PRP'),
#  ('thought', 'VBD'),
#  ('we', 'PRP'),
#  ('knew', 'VBD'),
#  ('so', 'RB'),
#  ('well', 'RB'),
#  ("''", "''"),
#  ('.', '.'),
#  ('``', '``'),
#  ('Bloom', 'NNP'),
#  ('recognizes', 'VBZ'),
#  ('the', 'DT'),
#  ('darker', 'NN'),
#  ('aspects', 'NNS'),
#  ('of', 'IN'),
#  ('Andersen', 'NNP'),
#  ("'s", 'POS'),
#  ('authorship', 'NN'),
#  (',', ','),
#  ("''", "''"),
#  ('Prince', 'NNP'),
#  ('Frederik', 'NNP'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('Bloom', 'NNP'),
#  ('is', 'VBZ'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('formally', 'RB'),
#  ('presented', 'VBN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('Hans', 'NNPS'),
#  ('Christian', 'JJ'),
#  ('Andersen', 'NNP'),
#  ('Award', 'NNP'),
#  ('this', 'DT'),
#  ('spring', 'NN'),
#  ('in', 'IN'),
#  ('Anderson', 'NNP'),
#  ("'s", 'POS'),
#  ('hometown', 'NN'),
#  ('of', 'IN'),
#  ('Odense', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('royal', 'JJ'),
#  ('couple', 'NN'),
#  ('also', 'RB'),
#  ('visited', 'VBD'),
#  ('the', 'DT'),
#  ('Hans', 'NNPS'),
#  ('Christian', 'NNP'),
#  ('Anderson', 'NNP'),
#  ('School', 'NNP'),
#  ('complex', 'NN'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('Queen', 'NNP'),
#  ('Mary', 'NNP'),
#  ('read', 'VBD'),
#  ('The', 'DT'),
#  ('Ugly', 'NNP'),
#  ('Duckling', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('young', 'JJ'),
#  ('audience', 'NN'),
#  ('.', '.'),
#  ('Later', 'RB'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('gala', 'NN'),
#  ('dinner', 'NN'),
#  (',', ','),
#  ('Danish', 'NNP'),
#  ('supermodel', 'FW'),
#  ('Helena', 'NNP'),
#  ('Christensen', 'NNP'),
#  ('was', 'VBD'),
#  ('named', 'VBN'),
#  ('a', 'DT'),
#  ('Hans', 'NNP'),
#  ('Christian', 'NNP'),
#  ('Andersen', 'NNP'),
#  ('ambassador', 'NN'),
#  ('.', '.'),
#  ('Other', 'JJ'),
#  ('ambassadors', 'NNS'),
#  ('include', 'VBP'),
#  ('actors', 'NNS'),
#  ('Harvey', 'NNP'),
#  ('Keitel', 'NNP'),
#  ('and', 'CC'),
#  ('Sir', 'NNP'),
#  ('Roger', 'NNP'),
#  ('Moore', 'NNP'),
#  (',', ','),
#  ('athlete', 'JJ'),
#  ('Cathy', 'NNP'),
#  ('Freeman', 'NNP'),
#  ('and', 'CC'),
#  ('Brazilian', 'JJ'),
#  ('soccer', 'NN'),
#  ('legend', 'NN'),
#  ('Pele', 'NNP'),
#  ('.', '.'),
#  ('Musical', 'NNP'),
#  ('treatment', 'NN'),
#  ('for', 'IN'),
#  ('Capra', 'NNP'),
#  ('film', 'NN'),
#  ('The', 'DT'),
#  ('classic', 'JJ'),
#  ('film', 'NN'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('A', 'DT'),
#  ('Wonderful', 'JJ'),
#  ('Life', 'NN'),
#  ('is', 'VBZ'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('turned', 'VBN'),
#  ('into', 'IN'),
#  ('a', 'DT'),
#  ('musical', 'JJ'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('producer', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('controversial', 'JJ'),
#  ('hit', 'NN'),
#  ('show', 'NN'),
#  ('Jerry', 'NNP'),
#  ('Springer', 'NNP'),
#  ('-', ':'),
#  ('The', 'DT'),
#  ('Opera', 'NNP'),
#  ('.', '.'),
#  ('Frank', 'NNP'),
#  ('Capra', 'NNP'),
#  ("'s", 'POS'),
#  ('1946', 'CD'),
#  ('movie', 'NN'),
#  ('starring', 'VBG'),
#  ('James', 'NNP'),
#  ('Stewart', 'NNP'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('being', 'VBG'),
#  ('turned', 'VBN'),
#  ('into', 'IN'),
#  ('a', 'DT'),
#  ('£7m', 'JJ'),
#  ('musical', 'JJ'),
#  ('by', 'IN'),
#  ('producer', 'NN'),
#  ('Jon', 'NNP'),
#  ('Thoday', 'NNP'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('is', 'VBZ'),
#  ('working', 'VBG'),
#  ('with', 'IN'),
#  ('Steve', 'NNP'),
#  ('Brown', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('wrote', 'VBD'),
#  ('the', 'DT'),
#  ('award-winning', 'JJ'),
#  ('musical', 'JJ'),
#  ('Spend', 'NNP'),
#  ('Spend', 'NNP'),
#  ('Spend', 'NNP'),
#  ('.', '.'),
#  ('A', 'NNP'),
#  ('spokeswoman', 'NN'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('plans', 'NNS'),
#  ('were', 'VBD'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('``', '``'),
#  ('very', 'RB'),
#  ('early', 'JJ'),
#  ('stages', 'NNS'),
#  ("''", "''"),
#  (',', ','),
#  ('with', 'IN'),
#  ('no', 'DT'),
#  ('cast', 'NN'),
#  (',', ','),
#  ('opening', 'VBG'),
#  ('date', 'NN'),
#  ('or', 'CC'),
#  ('theatre', 'NN'),
#  ('announced', 'VBN'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('series', 'NN'),
#  ('of', 'IN'),
#  ('workshops', 'NNS'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('held', 'VBN'),
#  ('in', 'IN'),
#  ('London', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('on', 'IN'),
#  ('Wednesday', 'NNP'),
#  ('a', 'DT'),
#  ('cast', 'NN'),
#  ('of', 'IN'),
#  ('singers', 'NNS'),
#  ('unveiled', 'VBD'),
#  ('the', 'DT'),
#  ('musical', 'JJ'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('select', 'JJ'),
#  ('group', 'NN'),
#  ('of', 'IN'),
#  ('potential', 'JJ'),
#  ('investors', 'NNS'),
#  ('.', '.'),
#  ('Mr', 'NNP'),
#  ('Thoday', 'NNP'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('idea', 'NN'),
#  ('of', 'IN'),
#  ('turning', 'VBG'),
#  ('the', 'DT'),
#  ('film', 'NN'),
#  ('into', 'IN'),
#  ('a', 'DT'),
#  ('musical', 'JJ'),
#  ('had', 'VBD'),
#  ('been', 'VBN'),
#  ('an', 'DT'),
#  ('ambition', 'NN'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('for', 'IN'),
#  ('almost', 'RB'),
#  ('20', 'CD'),
#  ('years', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('a', 'DT'),
#  ('Wonderful', 'JJ'),
#  ('Life', 'NNP'),
#  ('was', 'VBD'),
#  ('based', 'VBN'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('short', 'JJ'),
#  ('story', 'NN'),
#  (',', ','),
#  ('The', 'DT'),
#  ('Greatest', 'NNP'),
#  ('Gift', 'NNP'),
#  (',', ','),
#  ('by', 'IN'),
#  ('Philip', 'NNP'),
#  ('van', 'NN'),
#  ('Doren', 'NNP'),
#  ('Stern', 'NNP'),
#  ('.', '.'),
#  ('Mr', 'NNP'),
#  ('Thoday', 'NNP'),
#  ('managed', 'VBD'),
#  ('to', 'TO'),
#  ('buy', 'VB'),
#  ('the', 'DT'),
#  ('rights', 'NNS'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('story', 'NN'),
#  ('from', 'IN'),
#  ('Van', 'NNP'),
#  ('Doren', 'NNP'),
#  ('Stern', 'NNP'),
#  ("'s", 'POS'),
#  ('family', 'NN'),
#  ('in', 'IN'),
#  ('1999', 'CD'),
#  (',', ','),
#  ('following', 'VBG'),
#  ('Mr', 'NNP'),
#  ('Brown', 'NNP'),
#  ("'s", 'POS'),
#  ('success', 'NN'),
#  ('with', 'IN'),
#  ('Spend', 'NNP'),
#  ('Spend', 'NNP'),
#  ('Spend', 'NNP'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('later', 'RB'),
#  ('secured', 'VBD'),
#  ('the', 'DT'),
#  ('film', 'NN'),
#  ('rights', 'NNS'),
#  ('from', 'IN'),
#  ('Paramount', 'NNP'),
#  (',', ','),
#  ('enabling', 'VBG'),
#  ('them', 'PRP'),
#  ('to', 'TO'),
#  ('use', 'VB'),
#  ('the', 'DT'),
#  ('title', 'NN'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('A', 'DT'),
#  ('Wonderful', 'JJ'),
#  ('Life', 'NNP'),
#  ('.', '.'),
#  ('Richard', 'NNP'),
#  ('and', 'CC'),
#  ('Judy', 'NNP'),
#  ('choose', 'VBP'),
#  ('top', 'JJ'),
#  ('books', 'NNS'),
#  ('The', 'DT'),
#  ('10', 'CD'),
#  ('authors', 'NNS'),
#  ('shortlisted', 'VBD'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('Richard', 'NNP'),
#  ('and', 'CC'),
#  ('Judy', 'NNP'),
#  ('book', 'NN'),
#  ('award', 'NN'),
#  ('in', 'IN'),
#  ('2005', 'CD'),
#  ('are', 'VBP'),
#  ('hoping', 'VBG'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('boost', 'NN'),
#  ('in', 'IN'),
#  ('sales', 'NNS'),
#  ('following', 'VBG'),
#  ('the', 'DT'),
#  ('success', 'NN'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('year', 'NN'),
#  ("'s", 'POS'),
#  ('winner', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('TV', 'NN'),
#  ('couple', 'NN'),
#  ("'s", 'POS'),
#  ('interest', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('book', 'NN'),
#  ('world', 'NN'),
#  ('coined', 'VBD'),
#  ('the', 'DT'),
#  ('term', 'NN'),
#  ('``', '``'),
#  ('the', 'DT'),
#  ('Richard', 'NNP'),
#  ('&', 'CC'),
#  ('Judy', 'NNP'),
#  ('effect', 'NN'),
#  ("''", "''"),
#  ('and', 'CC'),
#  ('created', 'VBD'),
#  ('the', 'DT'),
#  ('top', 'JJ'),
#  ('two', 'CD'),
#  ('best-selling', 'JJ'),
#  ('paperbacks', 'NNS'),
#  ('of', 'IN'),
#  ('2004', 'CD'),
#  ('so', 'RB'),
#  ('far', 'RB'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('finalists', 'NNS'),
#  ('for', 'IN'),
#  ('2005', 'CD'),
#  ('include', 'VBP'),
#  ('Andrew', 'NNP'),
#  ('Taylor', 'NNP'),
#  ("'s", 'POS'),
#  ('The', 'DT'),
#  ('American', 'JJ'),
#  ('Boy', 'NNP'),
#  ('and', 'CC'),
#  ('Robbie', 'NNP'),
#  ('Williams', 'NNP'),
#  ("'", 'POS'),
#  ('autobiography', 'NN'),
#  ('Feel', 'NNP'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('year', 'NN'),
#  ("'s", 'POS'),
#  ('winner', 'NN'),
#  (',', ','),
#  ('Alice', 'NNP'),
#  ('Sebold', 'NNP'),
#  ("'s", 'POS'),
#  ('The', 'DT'),
#  ('Lovely', 'NNP'),
#  ('Bones', 'NNP'),
#  (',', ','),
#  ('sold', 'VBD'),
#  ('over', 'RP'),
#  ('one', 'CD'),
#  ('million', 'CD'),
#  ('.', '.'),
#  ('Joseph', 'NNP'),
#  ("O'Connor", 'NNP'),
#  ("'s", 'POS'),
#  ('Star', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Sea', 'NNP'),
#  ('came', 'VBD'),
#  ('second', 'JJ'),
#  ('and', 'CC'),
#  ('saw', 'VBD'),
#  ('sales', 'NNS'),
#  ('increase', 'VB'),
#  ('by', 'IN'),
#  ('350', 'CD'),
#  ('%', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('best', 'JJS'),
#  ('read', 'JJ'),
#  ('award', 'NN'),
#  (',', ','),
#  ('on', 'IN'),
#  ('Richard', 'NNP'),
#  ('Madeley', 'NNP'),
#  ('and', 'CC'),
#  ('Judy', 'NNP'),
#  ('Finnigan', 'NNP'),
#  ("'s", 'POS'),
#  ('Channel', 'NNP'),
#  ('4', 'CD'),
#  ('show', 'NN'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('British', 'JJ'),
#  ('Book', 'NNP'),
#  ('Awards', 'NNP'),
#  ('.', '.'),
#  ('David', 'NNP'),
#  ('Mitchell', 'NNP'),
#  ("'s", 'POS'),
#  ('Booker-shortlisted', 'JJ'),
#  ('novel', 'NN'),
#  (',', ','),
#  ('Cloud', 'NNP'),
#  ('Atlas', 'NNP'),
#  (',', ','),
#  ('makes', 'VBZ'),
#  ('it', 'PRP'),
#  ('into', 'IN'),
#  ('this', 'DT'),
#  ('year', 'NN'),
#  ("'s", 'POS'),
#  ('top', 'JJ'),
#  ('10', 'CD'),
#  ('along', 'IN'),
#  ('with', 'IN'),
#  ('several', 'JJ'),
#  ('lesser', 'JJR'),
#  ('known', 'VBN'),
#  ('works', 'NNS'),
#  ('.', '.'),
#  ('``', '``'),
#  ('There', 'EX'),
#  ("'s", 'VBZ'),
#  ('no', 'DT'),
#  ('doubt', 'NN'),
#  ('that', 'IN'),
#  ('this', 'DT'),
#  ('year', 'NN'),
#  ("'s", 'POS'),
#  ('selection', 'NN'),
#  ('of', 'IN'),
#  ('book', 'NN'),
#  ('club', 'NN'),
#  ('entries', 'NNS'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('best', 'JJS'),
#  ('yet', 'RB'),
#  ('.', '.'),
#  ('If', 'IN'),
#  ('anything', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('choice', 'NN'),
#  ('is', 'VBZ'),
#  ('even', 'RB'),
#  ('wider', 'JJR'),
#  ('than', 'IN'),
#  ('last', 'JJ'),
#  ('time', 'NN'),
#  (',', ','),
#  ("''", "''"),
#  ('said', 'VBD'),
#  ('Madeley', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('It', 'PRP'),
#  ('was', 'VBD'),
#  ('very', 'RB'),
#  ('hard', 'JJ'),
#  ('to', 'TO'),
#  ('follow', 'VB'),
#  ('last', 'JJ'),
#  ('year', 'NN'),
#  ("'s", 'POS'),
#  ('extremely', 'RB'),
#  ('successful', 'JJ'),
#  ('list', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('we', 'PRP'),
#  ('think', 'VBP'),
#  ('this', 'DT'),
#  ('year', 'NN'),
#  ("'s", 'POS'),
#  ('books', 'NNS'),
#  ('will', 'MD'),
#  ('do', 'VB'),
#  ('even', 'RB'),
#  ('better', 'RBR'),
#  (',', ','),
#  ("''", "''"),
#  ('said', 'VBD'),
#  ('Richard', 'NNP'),
#  ('and', 'CC'),
#  ('Judy', 'NNP'),
#  ('executive', 'NN'),
#  ('producer', 'NN'),
#  ('Amanda', 'NNP'),
#  ('Ross', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('We', 'PRP'),
#  ('were', 'VBD'),
#  ('spoiled', 'VBN'),
#  ('for', 'IN'),
#  ('choice', 'NN'),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('tough', 'JJ'),
#  ('getting', 'VBG'),
#  ('down', 'RB'),
#  ('to', 'TO'),
#  ('only', 'RB'),
#  ('10', 'CD'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('301', 'CD'),
#  ('submitted', 'VBD'),
#  ('.', '.'),
#  ("''", "''"),
#  ('Poppins', 'VBZ'),
#  ('musical', 'JJ'),
#  ('gets', 'VBZ'),
#  ('flying', 'VBG'),
#  ('start', 'VB'),
#  ('The', 'DT'),
#  ('stage', 'NN'),
#  ('adaptation', 'NN'),
#  ('of', 'IN'),
#  ('children', 'NNS'),
#  ("'s", 'POS'),
#  ('film', 'NN'),
#  ('Mary', 'NNP'),
#  ('Poppins', 'NNP'),
#  ('has', 'VBZ'),
#  ('had', 'VBD'),
#  ('its', 'PRP$'),
#  ('opening', 'VBG'),
#  ('night', 'NN'),
#  ('in', 'IN'),
#  ('London', 'NNP'),
#  ("'s", 'POS'),
#  ('West', 'NNP'),
#  ('End', 'NN'),
#  ('.', '.'),
#  ('Sir', 'NNP'),
#  ...]

# %% [markdown]
# ## Using nltk.ne_chunk for NER

# %%
entities = nltk.ne_chunk(tagged, binary=True)

# %%
len(entities)
# Out:
# 32143

# %%
entities_list = []
for t in entities.subtrees():
    if t.label() == 'NE':
        e_tuples = list(t)
        s = ''
        for tup in e_tuples:
            s += tup[0] + ' '
        entities_list.append(s[:-1])

# %%
entities_list
# Out:
# ['Gallery',
#  'London',
#  'Tate Britain',
#  'Tate',
#  'Richard Wentworth',
#  'Tate',
#  'Tracey Emin',
#  'Norway',
#  'ArtWorks',
#  'Wentworth',
#  'Henry Moore',
#  'Wentworth',
#  'Jarre',
#  'French',
#  'Copenhagen',
#  'Denmark',
#  'Parken',
#  'Danish',
#  'Christian Andersen',
#  'Jarre',
#  'Andersen',
#  'Emperor',
#  'New Clothes',
#  'Little Mermaid',
#  'Denmark',
#  'Crown Princess Mary',
#  'New York',
#  'Manhattan',
#  'US',
#  'Harold Bloom',
#  'Andersen',
#  'Frederik',
#  'Bloom',
#  'Christian Andersen Award',
#  'Anderson',
#  'Odense',
#  'Christian Anderson School',
#  'Queen Mary',
#  'Ugly Duckling',
#  'Danish',
#  'Helena Christensen',
#  'Harvey Keitel',
#  'Sir Roger Moore',
#  'Cathy Freeman',
#  'Brazilian',
#  'Capra',
#  'Jerry Springer',
#  'Frank Capra',
#  'James Stewart',
#  'Jon',
#  'Steve Brown',
#  'London',
#  'Greatest Gift',
#  'Philip',
#  'Doren Stern',
#  'Van Doren Stern',
#  'Brown',
#  'Spend Spend Spend',
#  'Paramount',
#  'Richard',
#  'Richard',
#  'Judy',
#  'Richard',
#  'Andrew Taylor',
#  'American Boy',
#  'Robbie Williams',
#  'Alice Sebold',
#  'Lovely Bones',
#  'Joseph',
#  'Sea',
#  'Richard Madeley',
#  'Judy Finnigan',
#  'British Book Awards',
#  'David Mitchell',
#  'Cloud Atlas',
#  'Madeley',
#  'Richard',
#  'Judy',
#  'Amanda Ross',
#  'London',
#  'West End',
#  'Laura Michelle Kelly',
#  'Barbara Windsor',
#  'Graham Norton',
#  'Sir Richard Attenborough',
#  'Richard Eyre',
#  'Pamela Travers',
#  'Disney',
#  'Julie Andrews',
#  'Bennett',
#  'History Boys',
#  'Alan Bennett',
#  'Circle Theatre Awards',
#  'Richard Griffiths',
#  'Victoria Hamilton',
#  'Suddenly',
#  'Festen',
#  'Rufus Norris',
#  'History Boys',
#  'Alan Bennett',
#  'History Boys',
#  'London',
#  'Circle',
#  'Rebecca Lenkiewicz',
#  'Night Season',
#  'Eddie Redmayne',
#  'Sylvia',
#  'Paul Rhys',
#  'National Theatre',
#  'Christopher Oram',
#  'Suddenly',
#  'Circle',
#  'US',
#  'Christian Slater',
#  'Cuckoo',
#  'Diana Rigg',
#  'Suddenly',
#  'Dame Judi Dench',
#  'RSC',
#  'Ends Well',
#  'History Boys',
#  'Samuel Barnett',
#  'Levy',
#  'Novelist Andrea Levy',
#  'Small Island',
#  'Orange Prize',
#  'Scots',
#  'John Guy',
#  'Sir Trevor McDonald',
#  'Joanne Harris',
#  'Small Island',
#  'Levy',
#  'London',
#  'British',
#  'Hitler',
#  'Guy',
#  'Scots',
#  'Guy',
#  'Tudor England',
#  'Clare College',
#  'Cambridge',
#  'University',
#  'Susan Fletcher',
#  'University',
#  'East Anglia',
#  'Corpus',
#  'Michael Symmons Roberts',
#  'Symmons Roberts',
#  'Geraldine',
#  'McCaughrean',
#  'McCaughrean',
#  'Gold Dust',
#  'West',
#  'West End',
#  'London',
#  'Nathan Lane',
#  'Lee Evans',
#  'National Theatre',
#  'Sweeney Todd',
#  'Sylvia',
#  'Edward Albee',
#  'Martin McDonagh',
#  'Alan Bennett',
#  'History Boys',
#  'Victoria Hamilton',
#  'Kelly Reilly',
#  'Ferris',
#  'May',
#  'Royal Court Theatre',
#  'Richard Griffiths',
#  'History Boys',
#  'National Theatre',
#  'Douglas Hodge',
#  'Dumb Show',
#  'Stanley Townsend',
#  'Luc Bondy',
#  'Cruel',
#  'Tender',
#  'Simon McBurney',
#  'Measure',
#  'Rufus Norris',
#  'Festen',
#  'Festen',
#  'Ian MacNeil',
#  'Jean Kalman',
#  'Paul Arditti',
#  'Hildegard Bechtler',
#  'Iphigenia',
#  'Aulis',
#  'Paul Brown',
#  'False Servant',
#  'Milton Shulman Award',
#  'Dominic Cooper',
#  'Dark Materials',
#  'History Boys',
#  'Romola Garai',
#  'Calico',
#  'Eddie Redmayne',
#  'Goat',
#  'Sylvia',
#  'Ben Wishaw',
#  'Hamlet',
#  'David Eldridge',
#  'Rebecca Lenkiewicz',
#  'Owen McCafferty',
#  'Charles Wintour Award',
#  'Jesus',
#  'Church',
#  'Bishop',
#  'Durham',
#  'Dan Brown',
#  'Bishop',
#  'Northern Echo',
#  'Bishop',
#  'Dan Brown',
#  'Biblical',
#  'Jesus',
#  'Bishop',
#  'Jesus',
#  'Christianity',
#  'New Testament',
#  'Cicero',
#  'Virgil',
#  'Tacitus',
#  'Jesus',
#  'Brown',
#  'US',
#  'Tom Hanks',
#  'Uganda',
#  'Vagina Monologues Uganda',
#  'Vagina Monologues',
#  'Kampala',
#  'Ugandan Media Council',
#  'Media Council',
#  'Uganda',
#  'New Vision',
#  'US',
#  'Ensler',
#  'BBC',
#  'Ugandan',
#  'Ugandan',
#  'Uganda',
#  'Sarah Mukasa',
#  'BBC',
#  'Africa',
#  'Uganda',
#  'Damien Hirst',
#  'Tracey Emin',
#  'Royal Academy',
#  'Arts',
#  'Mario Testino',
#  'RCA',
#  'Bradburn',
#  'Ken Loach',
#  'Hussein Chalayan',
#  'Blur',
#  'Graham Coxon',
#  'Royal College',
#  'Art',
#  'RCA',
#  'Liam Neeson',
#  'New York',
#  'Belfast',
#  'Lyric Theatre',
#  'Ridgeway Street',
#  'Lyric',
#  'David Johnston',
#  'Neeson',
#  'Irish Americans',
#  'Schindler',
#  'Michael Collins',
#  'Star Wars',
#  'Phantom Menace',
#  'Lyric',
#  'Northern Ireland',
#  'Belfast',
#  'Belisha',
#  'Shakespeare',
#  'Lyric',
#  'River Lagan',
#  'Liam Neeson',
#  'Adrian Dunbar',
#  'Stephen Rea',
#  'Martin Lynch',
#  'BBC Northern Ireland',
#  'New York',
#  'SoHo House',
#  'Neeson',
#  'Antrim',
#  'Ian Paisley',
#  'DUP',
#  'Neeson',
#  'Ballymena',
#  'Whitbread',
#  'Orange Prize',
#  'Andrea Levy',
#  'Small Island',
#  'Whitbread Novel',
#  'Year Award',
#  'Booker',
#  'Alan Hollinghurst',
#  'Beauty',
#  'Geraldine',
#  'McCaughrean',
#  'Whitbread Book',
#  'Year',
#  'Sir Trevor McDonald',
#  'Joanne Harris',
#  'Levy',
#  'Small Island',
#  'Levy',
#  'England',
#  'British',
#  'Hitler',
#  'London',
#  'Jenny Colgan',
#  'Amanda Craig',
#  'Susan Fletcher',
#  'Jonathan Strange',
#  'Susanna Clarke',
#  'University',
#  'East Anglia',
#  'Waterstone',
#  'Suzie Doore',
#  'Susan Fletcher',
#  'John Guy',
#  'Guy',
#  'Tudor England',
#  'Clare College',
#  'Cambridge',
#  'University',
#  'Michael Symmons Roberts',
#  'Symmons Roberts',
#  'Children',
#  'McCaughrean',
#  'Whitbread Prize',
#  'Gold Dust',
#  'Blue Peter Book',
#  'Fergus Crane',
#  'Book Prizes',
#  'Paul Stewart',
#  'Chris Riddell',
#  'Sally Grindley',
#  'Spilled Water',
#  'Chinese',
#  'Biscuit Bear',
#  'Mini Grey',
#  'UK',
#  'Fergus Crane',
#  'Stewart',
#  'Riddell',
#  'Edge Chronicles',
#  'JK Rowling',
#  'Jacqueline Wilson',
#  'Dick',
#  'Mutant',
#  'Guardian',
#  'Guardian First Book',
#  'Armand Marie Leroi',
#  'London',
#  'Claire Armistead',
#  'Hari Kunzru',
#  'Ali Smith',
#  'Sir Richard Eyre',
#  'Alexei Sayle',
#  'Susanna Clarke',
#  'Jonathan Strange',
#  'Century',
#  'Between',
#  'Rory Stewart',
#  'Afghanistan',
#  'Armand Marie Leroi',
#  'Guardian',
#  'Mutants',
#  'Iris',
#  'Sir Richard Eyre',
#  'Marie Leroi',
#  'White Teeth',
#  'Zadie Smith',
#  'Arthur Hailey',
#  'Novelist Arthur Hailey',
#  'Luton',
#  'Bedfordshire',
#  'Hailey',
#  'Royal Air Force',
#  'Middle East',
#  'Danger',
#  'Hailey',
#  'Canada',
#  'Toronto',
#  'Canadian Broadcasting Corporation',
#  'Flight',
#  'Danger',
#  'Leslie Nielsen',
#  'Hailey',
#  'Danger',
#  'Hailey',
#  'Runaway',
#  'Final Diagnosis',
#  'High Places',
#  'Hotel',
#  'Hollywood',
#  'James Brolin',
#  'Hailey',
#  'Burt Lancaster',
#  'Dean Martin',
#  'Jean Seberg',
#  'Jacqueline Bisset',
#  'Nassau',
#  'Bahamas',
#  'Overload',
#  'Hailey',
#  'Hollywood',
#  'Strong Medicine',
#  'Hailey',
#  'Sam Neill',
#  'Douglas Fairbanks Jr',
#  'Hailey',
#  'Hailey',
#  'New Providence',
#  'Sheila',
#  'Spark',
#  'Dame Muriel Spark',
#  'British',
#  'Booker Prize',
#  'Doris Lessing',
#  'Ian',
#  'McEwan',
#  'Margaret Atwood',
#  'Booker Prize',
#  'English',
#  'Gabriel Garcia Marquez',
#  'Saul Bellow',
#  'Milan Kundera',
#  'John Updike',
#  'Booker Prize',
#  'Salman Rushdie',
#  'JM Coetzee',
#  'Kazuo Ishiguro',
#  'London',
#  'Booker Prize',
#  'British',
#  'Margaret Atwood',
#  'Canada',
#  'Saul Bellow',
#  'Canada',
#  'Gabriel Garcia Marquez',
#  'Colombia',
#  'Germany',
#  'Ismail Kadare',
#  'Albania',
#  'Milan Kundera',
#  'Czech Republic',
#  'Poland',
#  'Doris Lessing',
#  'Ian',
#  'Naguib Mahfouz',
#  'Egypt',
#  'Tomas Eloy Martinez',
#  'Argentina',
#  'Kenzaburo Oe',
#  'Japan',
#  'Cynthia Ozick',
#  'US',
#  'Philip Roth',
#  'US',
#  'Muriel Spark',
#  'Antonio Tabucchi',
#  'Italy',
#  'John Updike',
#  'US',
#  'Abraham',
#  'Israel',
#  'Gianni Versace',
#  'New York',
#  'London',
#  'Roy Lichtenstein',
#  'Andy Warhol',
#  'Henri Matisse',
#  'Versace',
#  'New York',
#  'Florida',
#  'Andrew Cunanan',
#  'Sotheby',
#  'Century',
#  'Roy Lichtenstein',
#  'Blue Nude',
#  'Tobias Meyer',
#  'Sotheby',
#  'Pop',
#  'Roy Lichtenstein',
#  'Basquiat',
#  'Warhol',
#  'Francesco Clemente',
#  'New York',
#  'London',
#  'Versace',
#  'Broadway',
#  'Broadway',
#  'Glass Menagerie',
#  'Dallas Roberts',
#  'Tennessee Williams',
#  'Roberts',
#  'Joey Collins',
#  'Slater',
#  'Cuckoo',
#  'London',
#  'West End',
#  'Robin Hood',
#  'Hollywood Years',
#  'Glass Menagerie',
#  'New York',
#  'Ethel Barrymore Theatre',
#  'Philip Rinaldi',
#  'David Leveaux',
#  'Jessica Lange',
#  'Amanda Wingfield',
#  'Reynolds',
#  'Omai',
#  'Tate Gallery',
#  'Century',
#  'Reynolds',
#  'Tate Britain',
#  'Joshua Reynolds',
#  'Celebrity',
#  'Century',
#  'Omai',
#  'British',
#  'London',
#  'Tate',
#  'London',
#  'Polynesia',
#  'London',
#  'Royal Academy',
#  'Alicia Markova Dame Alicia Markova',
#  'Bath',
#  'UK',
#  'Lilian Alicia Marks',
#  'London',
#  'Rolls Royce',
#  'Russian',
#  'Sergei Diaghilev',
#  'Ballets Russes',
#  'Diaghilev',
#  'Monte Carlo',
#  'Europe',
#  'Matisse',
#  'Stravinsky',
#  'Diaghilev',
#  'Alicia Markova',
#  'England',
#  'Britain',
#  'Ballet Club',
#  'Mercury Theatre',
#  'Ballet Rambert',
#  'Vic Wells Ballet',
#  'Anton Dolin',
#  'Anthony Tudor',
#  'Frederick Ashton',
#  'Giselle',
#  'British',
#  'Les Sylphides',
#  'Britain',
#  'America',
#  'Alicia Markova',
#  'United States',
#  'Ballets Russes',
#  'Hollywood',
#  'England',
#  'Anton Dolin',
#  'Festival Ballet',
#  'Metropolitan Opera Ballet',
#  'New York',
#  'Ballet',
#  'University',
#  'Cincinnati',
#  'Dame Alicia Markova',
#  'Darcey Bussell',
#  'Royal Academy',
#  'Dance',
#  'RAD',
#  'British',
#  'RAD',
#  'BBC News',
#  'Gameboys',
#  'Hazel Gilbert',
#  'Newcastle',
#  'Gateshead',
#  'Royal Ballet',
#  'Darcey Bussell',
#  'Jonathan Cope',
#  'British',
#  'English National Ballet',
#  'BBC News',
#  'British',
#  'London',
#  'British',
#  'RAD',
#  'Fonteyn Nureyev Young Dancers',
#  'British',
#  'RAD',
#  'Viotti',
#  'Conductor Marcello Viotti',
#  'Venice',
#  'Germany',
#  'Viotti',
#  'Milan',
#  'Vienna State Opera',
#  'La Fenice',
#  'Jules Massenet',
#  'Berlin Philharmonic',
#  'English',
#  'Viotti',
#  'Switzerland',
#  'Lausanne Conservatory',
#  'Gino',
#  'Italy',
#  'Viotti',
#  'Turin Opera',
#  'Munich',
#  'Radio Orchestra',
#  'La Fenice Viotti',
#  'French',
#  'Massenet',
#  'Giuseppe Verdi',
#  'Richard Strauss',
#  'Ariadne',
#  'La Fenice',
#  'Massenet',
#  'Lahore',
#  'Viotti',
#  'New York',
#  'Metropolitan Opera',
#  'Giacomo Puccini',
#  'Madame Butterfly',
#  'La Boheme',
#  'La Traviata',
#  'Fromental Halevy',
#  'Giampaolo Vianello',
#  'Fenice Theatre Foundation',
#  'Viotti',
#  'Vincenzo Bellini',
#  'Vienna State Opera',
#  'Paraguay',
#  'US',
#  'Paraguay',
#  'US National Book Awards',
#  'Lily Tuck',
#  'News From Paraguay',
#  'Paraguayan',
#  'Francisco Solano Lopez',
#  'Irish',
#  'New York',
#  'Children',
#  'Blume',
#  'Blume',
#  'Stephen King',
#  'Philip Roth',
#  'Plot Against America',
#  'New',
#  "Stewart O'Nan",
#  'National Book Awards',
#  'Kevin Boyle',
#  'US',
#  'Pete Hautman',
#  'Jean Valentine',
#  'Collected Poems',
#  'New Harry',
#  'Harry Potter',
#  'Amazon',
#  'US',
#  'Canada',
#  'Australia',
#  'New Zealand',
#  'South Africa',
#  'Harry Potter',
#  'Phoenix',
#  'Amazon',
#  'Harry Potter',
#  'Harry Potter',
#  'Amazon',
#  'Robin Terrell',
#  'Harry Potter',
#  'Harry Potter',
#  'Hogwarts School',
#  'Witchcraft',
#  'Wizardry',
#  'Lord Voldemort',
#  'Voldemort',
#  'National Gallery',
#  'UK',
#  'London',
#  'Raphael',
#  'Pinks',
#  'UK',
#  'Blackpool Pleasure Beach',
#  'Charles Saumarez Smith',
#  'Trafalgar Square',
#  'Russian',
#  'Tolstoy',
#  'Raphael',
#  'Urbino',
#  'Rome',
#  'Smith',
#  'Caravaggio',
#  'Stubbs',
#  'Rubens',
#  'Tate Modern',
#  'Natural History Museum',
#  'Buckingham Palace',
#  'Windsor Castle',
#  'Madame Tussauds',
#  'Alton Towers',
#  'Robin Broke',
#  'Western Europe',
#  'North America',
#  'European',
#  'Britain',
#  'Europe',
#  'Simon Cowell',
#  'Curtis Brown',
#  'Cowell',
#  'Paul Cavanagh',
#  'Harper Collins',
#  'London Book Fair',
#  'Cowell',
#  'Paul Cavanagh',
#  'Ontario',
#  'Canada',
#  'Northwest Passage',
#  'Warner',
#  'Harry Potter',
#  'Alfonso Cuaron',
#  'Hollywood',
#  'Warner Brothers',
#  'Variety',
#  'Mexican',
#  'Harry Potter',
#  'Azkaban',
#  'Alfonso',
#  'Harry Potter',
#  'Jeff Robinov',
#  'Variety',
#  'Cuaron',
#  'Mexican',
#  'Cuaron',
#  'Carlos',
#  'Warner',
#  'Cuaron',
#  'US',
#  'Alfonso',
#  'Warner Brothers',
#  'Frances Hodgson Burnett',
#  'New York',
#  'Cuaron',
#  'Harry Potter',
#  'Baghdad Blogger',
#  'Baghdad Blogger',
#  'Rotterdam Film Festival',
#  'Salam Pax',
#  'Iraqi',
#  'Pax',
#  'Baghdad Blogger',
#  'Iraq',
#  'Dutch',
#  'Salam Pax',
#  'Guardian',
#  'Iraq',
#  'Iraqis',
#  'Underexposure',
#  'Iraq',
#  'Saddam Hussein',
#  'Ministry',
#  'Culture',
#  'Baghdad',
#  'Rasheed',
#  'Iraqis',
#  'Saddam',
#  'Saddam',
#  'Rasheed',
#  'Dutch',
#  'Islam',
#  'Van Gogh',
#  'US',
#  'Sideways Road',
#  'Sideways',
#  'Chicago Film Critics Association',
#  'CFCA',
#  'Paul Giamatti',
#  'Clint Eastwood',
#  'Million Dollar Baby',
#  'Southeastern Film Critics',
#  'Jim Taylor',
#  'CFCA',
#  'Thomas Haden',
#  'Virginia',
#  'Sideways',
#  'New York',
#  'Los Angeles',
#  'Golden Globe',
#  'British',
#  'Imelda Staunton',
#  'CFCA',
#  'Vera Drake',
#  'Mike Leigh',
#  'Scrubs',
#  'Zach Braff',
#  'Garden State',
#  'Michael Moore',
#  'Long Engagement',
#  'Chicago',
#  'Den Watts',
#  'EastEnders',
#  'Den',
#  'BBC One',
#  'Den',
#  'Zoe',
#  'Chrissie',
#  'Queen Vic',
#  'ITV1',
#  'BBC',
#  'Den',
#  'Den',
#  'Leslie Grantham',
#  'Grantham',
#  'Redford',
#  'Robert Redford',
#  'Sundance',
#  'Park City',
#  'Utah',
#  'Sundance',
#  'Redford',
#  'Slamdance',
#  'XDance',
#  'Park City',
#  'Sundance',
#  'Redford',
#  'Redford',
#  'Hollywood',
#  'Hollywood',
#  'Redford',
#  'American',
#  'US',
#  'America',
#  'Iraq',
#  'Redford',
#  'Redford',
#  'African America',
#  'Asian',
#  'Harry Potter',
#  'Azkaban',
#  'Harry Potter',
#  'DVD',
#  'Alfonso Cuaron',
#  'Harry',
#  'Hogwarts',
#  'Harry',
#  'Ron',
#  'Harry',
#  'Daniel Radcliffe',
#  'Emma Watson',
#  'Hermione',
#  'Gary Oldman',
#  'Emma Thompson',
#  'Scabbers',
#  'Harry Potter',
#  'JK Rowling',
#  'Vera Drake',
#  'Mike Leigh',
#  'Imelda Staunton',
#  'British Film Awards',
#  'Vera Drake',
#  'Leigh',
#  'Staunton',
#  'Paddy Considine',
#  'Dead Man',
#  'Bridget Jones',
#  'Reason',
#  'London',
#  'Leigh',
#  'Timothy Spall',
#  'Staunton',
#  'Patrick Stewart',
#  'Savoy',
#  'Derek Malcolm',
#  'Leigh',
#  'Alexander Walker Special Award',
#  'British',
#  'Tim Bevan',
#  'Eric Fellner',
#  'Billy Elliot',
#  'Shaun',
#  'Bridget Jones',
#  'Reason',
#  'Simon Pegg',
#  'Comedy',
#  'Emily Blunt',
#  'Nathalie',
#  'ITV London',
#  'Pawel Pawlikowski',
#  'Love',
#  'Pawlikowski',
#  'Roger Deakins',
#  'Technical Achievement Award',
#  'Village',
#  'Dame Judi Dench',
#  'Kim Cattrall',
#  'Charles Dance',
#  'Bill Nighy',
#  'Colin Firth',
#  'Jack Dee',
#  'ITV London',
#  'Hundreds',
#  'Academy',
#  'Motion Picture',
#  'Arts',
#  'Sciences',
#  'Aviator',
#  'Million Dollar Baby',
#  'Sideways',
#  'Aviator',
#  'Leonardo',
#  'DiCaprio',
#  'US',
#  'Variety',
#  'Closer',
#  'Jude Law',
#  'Julia Roberts',
#  'Johnny Depp',
#  'Kinsey',
#  'Liam Neeson',
#  'Alfred Kinsey',
#  'Takuo Miyagishima',
#  'Scientific',
#  'Technical Awards Dinner',
#  'Sawyer Award',
#  'Los Angeles',
#  'Hanks',
#  'Tom Hanks',
#  'London',
#  'Polar Express',
#  'West',
#  'End',
#  'Hanks',
#  'Santa Claus',
#  'Santa',
#  'Hanks',
#  'Academy Award',
#  'Christmas',
#  'Santa Claus',
#  'Lord',
#  'Gollum',
#  'Hanks',
#  'Father Christmas',
#  'Robert Zemeckis',
#  'Hanks',
#  'Forrest Gump',
#  'Castaway',
#  'Pirates',
#  'Dominica',
#  'Carib Indians',
#  'Caribbean',
#  'Carib',
#  'Williams',
#  'Disney',
#  'Caribbean',
#  'Disney',
#  'Dominica',
#  'Disney',
#  'European',
#  'Dominica',
#  'Williams',
#  'Carib',
#  'Carib',
#  'Caribbean',
#  'US',
#  'Bafta',
#  'British Academy Film Awards',
#  'London',
#  'Hollywood',
#  'Cate Blanchett',
#  'Leonardo DiCaprio',
#  'Keanu Reeves',
#  'Richard Gere',
#  'Stephen Fry',
#  'UK',
#  'Gael Garcia Bernal',
#  'Imelda Staunton',
#  'Diane Kruger',
#  'Christian Slater',
#  'Anjelica Huston',
#  'Helen Mirren',
#  'James Bond',
#  'Pierce Brosnan',
#  'Aviator',
#  'DiCaprio',
#  'Eternal Sunshine',
#  'Spotless Mind',
#  'Motorcycle Diaries',
#  'British',
#  ...]

# %%
entities_freq = (word for word in entities_list if word[:1].isupper())
counter_entities = Counter(entities_freq)
print (counter_entities.most_common(10))
# Out:
# [('US', 59), ('Aviator', 34), ('Oscars', 33), ('Hollywood', 29), ('British', 29), ('London', 27), ('Million Dollar Baby', 24), ('Sideways', 20), ('French', 17), ('Harry Potter', 16)]

# %% [markdown]
# ## Using customized NER

# %%
grammar = "NP: {<DT>?<JJ>*<NN|NNS>}"
cp = nltk.RegexpParser(grammar)
entities_custom = cp.parse(tagged)

# %%
len(entities_custom)
# Out:
# 30521

# %%
entities_custom[:3]
# Out:
# [('Gallery', 'NNP'),
#  Tree('NP', [('unveils', 'JJ'), ('interactive', 'JJ'), ('tree', 'NN')]),
#  ('A', 'NNP')]

# %%
entities_custom_list = []
for subtree in entities_custom.subtrees():
    if subtree.label() == 'NP':
      entities_custom_list.append(' '.join(word for word, tag in subtree.leaves()))

# %%
entities_custom_list
# Out:
# ['unveils interactive tree',
#  'tree',
#  'text',
#  'messages',
#  'art gallery',
#  'The spruce',
#  'an antenna',
#  'visitors',
#  'The messages',
#  'sculptor',
#  'the tree',
#  'broken plates',
#  'light',
#  'bulbs',
#  'the 17th year',
#  'the gallery',
#  'an artist',
#  'tree',
#  'Artists',
#  'tree',
#  'previous years',
#  'The plain',
#  'spruce',
#  'the gallery',
#  'foyer',
#  'light bulb',
#  'adornments',
#  'ordinary domestic ones',
#  'string',
#  'The plates',
#  'the branches',
#  'the children',
#  'charity',
#  'an assistant',
#  'the late 1960s',
#  'reputation',
#  'a sculptor',
#  'influential teachers',
#  'decades',
#  'photography',
#  'mundane',
#  'everyday subjects',
#  'a cigarette',
#  'packet',
#  'the wonky leg',
#  'a table',
#  'fairytale celebration',
#  'a concert',
#  'the bicentennial',
#  'the birth',
#  'writer',
#  'a three-day celebration',
#  'the life',
#  'the fairy-tale author',
#  'a concert',
#  'stadium',
#  'Other stars',
#  'the line-up',
#  'the coming months',
#  'family',
#  'fairy',
#  'tales',
#  'any age',
#  'the pure enjoyment',
#  'the tale',
#  'a message',
#  'year-long celebrations',
#  'the world',
#  'work',
#  'the festivities',
#  'The pair',
#  'library',
#  'literary critic',
#  'the international icon',
#  'the darker',
#  'aspects',
#  'authorship',
#  'this spring',
#  'hometown',
#  'The royal couple',
#  'complex',
#  'the young audience',
#  'a gala',
#  'dinner',
#  'ambassador',
#  'Other ambassadors',
#  'actors',
#  'Brazilian soccer',
#  'legend',
#  'treatment',
#  'film',
#  'The classic film',
#  'A Wonderful Life',
#  'the producer',
#  'the controversial hit',
#  'show',
#  'movie',
#  'producer',
#  'spokeswoman',
#  'the plans',
#  'early stages',
#  'no cast',
#  'date',
#  'theatre',
#  'A series',
#  'workshops',
#  'a cast',
#  'singers',
#  'a select group',
#  'potential investors',
#  'the idea',
#  'the film',
#  'an ambition',
#  'years',
#  'a short story',
#  'van',
#  'the rights',
#  'the story',
#  'family',
#  'success',
#  'the film',
#  'rights',
#  'the title',
#  'top books',
#  'authors',
#  'book',
#  'award',
#  'a boost',
#  'sales',
#  'the success',
#  'this year',
#  'winner',
#  'The TV',
#  'couple',
#  'interest',
#  'the book',
#  'world',
#  'the term',
#  'effect',
#  'best-selling paperbacks',
#  'The finalists',
#  'autobiography',
#  'This year',
#  'winner',
#  'sales',
#  '%',
#  'read award',
#  'show',
#  'part',
#  'Booker-shortlisted novel',
#  'this year',
#  'works',
#  'no doubt',
#  'this year',
#  'selection',
#  'book',
#  'club',
#  'entries',
#  'anything',
#  'the choice',
#  'last time',
#  'last year',
#  'successful list',
#  'this year',
#  'books',
#  'executive',
#  'producer',
#  'choice',
#  'The stage',
#  'adaptation',
#  'children',
#  'film',
#  'night',
#  'End',
#  'lavish production',
#  'cost',
#  '£9m',
#  'the stage',
#  'a 10-minute standing',
#  'ovation',
#  'actress',
#  'the heads',
#  'the audience',
#  'the nanny',
#  'trademark',
#  'umbrella',
#  'Technical hitches',
#  'flight',
#  'the auditorium',
#  'preview',
#  'performances',
#  'A number',
#  'celebrities',
#  'the musical',
#  'premiere',
#  'actress',
#  'The show',
#  'director',
#  'a warning',
#  'the week',
#  'the show',
#  'children',
#  'under-threes',
#  'author',
#  'film',
#  'Travers',
#  'the story',
#  'a lot',
#  'darker',
#  'the perennial family',
#  'favourite',
#  'impresario',
#  'a blend',
#  'the sweet-natured film',
#  'the original book',
#  'play',
#  'new play',
#  'a grammar',
#  'school',
#  'the play',
#  'actor',
#  'prize',
#  'star',
#  'teacher',
#  'actress',
#  'director',
#  'new comedy',
#  'title',
#  'experience',
#  'a teacher',
#  'promising playwright',
#  'promising newcomer',
#  'Shakespearean performer',
#  'Measure',
#  'Measure',
#  'the design',
#  'award',
#  'award',
#  'winners',
#  'theatre fans',
#  'actor',
#  'actor',
#  'actress',
#  'actress',
#  'actor',
#  'book',
#  'the year',
#  'award',
#  'novel',
#  'the year',
#  'book',
#  'The book',
#  'fiction',
#  'favourite',
#  'the £25,000',
#  'favourite',
#  'a biography',
#  'panel',
#  'judges',
#  'actor',
#  'writer',
#  'the overall winner',
#  'writers',
#  'line',
#  'the award',
#  'respective categories',
#  'novel',
#  'novel',
#  'biography',
#  'poetry',
#  'children',
#  'book',
#  'fourth novel',
#  'centres',
#  'lodgers',
#  'British troops',
#  'life',
#  'uniform',
#  'preachy prospect',
#  'humane',
#  'eye-popping',
#  'anybody',
#  'the judges',
#  'The judges',
#  'readable piece',
#  'scholarship',
#  'the reader',
#  'queens',
#  'many histories',
#  'a fellow',
#  'a honorary research',
#  'professor',
#  'The other contenders',
#  'the first novel prize',
#  'creative writing',
#  'course',
#  'The fourth book',
#  'the running',
#  'fourth collection',
#  'poems',
#  'poetry',
#  'documentary films',
#  'the final contender',
#  'the children',
#  'fiction',
#  'category',
#  'the third time',
#  'the End',
#  'magazine',
#  'publishing',
#  'teaching',
#  'the category',
#  'Angels',
#  'End',
#  'finest',
#  'End',
#  'stars',
#  'the ceremony',
#  'the award',
#  'play',
#  'category',
#  'actress',
#  'known',
#  'television',
#  'roles',
#  'programmes',
#  'the shortlist',
#  'role',
#  'Notes',
#  'Leaves',
#  'battle',
#  'actor',
#  'award',
#  'director',
#  'shortlist',
#  'Measure',
#  'Measure',
#  'designer',
#  'category',
#  'outstanding newcomer',
#  'playwrights',
#  'a £30,000',
#  'bursary',
#  'an institution',
#  'a playwright',
#  'an individual',
#  'The plot',
#  'an international bestseller',
#  'thousands',
#  'readers',
#  'present',
#  'a clergyman',
#  'a normal death',
#  'the novel',
#  'great thriller',
#  'lousy history',
#  'The book',
#  'copies',
#  'conspiracy',
#  'theory',
#  'a lack',
#  'evidence',
#  'claims',
#  'message',
#  'Conspiracy',
#  'theories',
#  'fun',
#  'fun',
#  'writer',
#  'the genre',
#  'anyone',
#  'anything',
#  '1st century',
#  'history',
#  'this underlying material',
#  'A great deal',
#  'credible evidence',
#  'version',
#  'life',
#  'The evidence',
#  'the origins',
#  'a hundred times',
#  'early manuscripts',
#  'the gospels',
#  'letters',
#  'the main classical authors',
#  'Historical research',
#  'a coherent',
#  'credible picture',
#  'all sorts',
#  'incidental',
#  'details',
#  'the time',
#  'the world',
#  'later legend',
#  'book',
#  'a publishing',
#  'phenomenon',
#  'book',
#  'charts',
#  'languages',
#  'own cottage',
#  'industry',
#  'publications',
#  'guides',
#  'the book',
#  'rebuttals',
#  'counter',
#  'claims',
#  'The book',
#  'an international best-seller',
#  'years',
#  'a film',
#  'authorities',
#  'the play',
#  'the capital',
#  'this weekend',
#  'the performance',
#  'glorified acts',
#  'lesbianism',
#  'homosexuality',
#  'the production',
#  'the organisers',
#  'the offending',
#  'parts',
#  'the organisers',
#  'the play',
#  'awareness',
#  'sexual abuse',
#  'women',
#  'The play',
#  'unnatural sexual acts',
#  'homosexuality',
#  'prostitution',
#  'the council',
#  'ruling',
#  'The show',
#  'a controversial sell-out',
#  'the world',
#  'female sexuality',
#  'strength',
#  'individual women',
#  'stories',
#  'monologues',
#  'Some parliamentarians',
#  'church',
#  'leaders',
#  'newspaper',
#  'reports',
#  'The play',
#  'the guise',
#  'women',
#  'liberation',
#  'parliament',
#  'the work',
#  'author',
#  'women',
#  'empowerment',
#  'some fear',
#  'the vagina',
#  'the word',
#  'vagina',
#  'a slang',
#  'word',
#  'dirty',
#  'word',
#  'anatomical word',
#  'the play',
#  'women',
#  'the play',
#  'money',
#  'campaign',
#  'violence',
#  'women',
#  'funds',
#  'the war-torn north',
#  'the country',
#  'the hypocrisy',
#  'the play',
#  'organiser',
#  'programme',
#  'this country',
#  'the impression',
#  'women',
#  'rights',
#  'the notions',
#  'free speech',
#  'women',
#  'share',
#  'stories',
#  'the government',
#  'the apparatus',
#  'state',
#  'secret postcards',
#  'sale',
#  'Postcards',
#  'artists',
#  'hours',
#  'the opening',
#  'sale',
#  'The identity',
#  'the artist',
#  'each work',
#  'the signature',
#  'the back',
#  'some big names',
#  'spokeswoman',
#  'All postcards',
#  'The sale',
#  'a big queue',
#  'the start',
#  'the sale',
#  'the people',
#  'the famous name',
#  'postcards',
#  'time',
#  'each work',
#  'The exhibition',
#  'director',
#  'fashion',
#  'designer',
#  'guitarist',
#  'postcards',
#  'the sale',
#  'the contributing',
#  'artists',
#  'students',
#  'recent graduates',
#  'art',
#  'colleges',
#  'the sale',
#  'students',
#  'grants',
#  'bursaries',
#  'The famous sale',
#  'year',
#  'bid',
#  'film',
#  'star',
#  'a dinner',
#  'party',
#  'actor',
#  'the theatre',
#  'dilapidated condition',
#  'chairman',
#  'the theatre',
#  'a cost',
#  '£8m',
#  'the only answer',
#  'the idea',
#  'a bunch',
#  'room',
#  'fundraising',
#  'The Oscar-nominated actor',
#  'films',
#  'social life',
#  'this building',
#  'a start',
#  'the founder',
#  'the theatre',
#  'future',
#  'those days',
#  'the mid-70s',
#  'a play',
#  'weeks',
#  'town',
#  'serious trouble',
#  'this theatre',
#  'beacon',
#  'light',
#  'hope',
#  'nights',
#  'a week',
#  'everything',
#  'a group',
#  'actors',
#  'actresses',
#  'years',
#  'the doors',
#  'present site',
#  'embankment',
#  'the careers',
#  'playwrights',
#  'the event',
#  'spirit',
#  'figure',
#  'childhood',
#  'the big screen',
#  'leader',
#  'preacher',
#  'extraordinary figure',
#  'sermons',
#  'night',
#  'an orator',
#  'old school',
#  'bible-thumping righteousness',
#  'a chance',
#  'some time',
#  'novel',
#  'prize',
#  'winner',
#  'book',
#  'the overall prize',
#  'winner',
#  'the children',
#  'fiction',
#  'award',
#  'the third time',
#  'the End',
#  'the category',
#  'winners',
#  'title',
#  'a £25,000 prize',
#  'A panel',
#  'judges',
#  'actor',
#  'writer',
#  'the overall winner',
#  'the announcement',
#  'novel',
#  'favourite',
#  'fourth novel',
#  'centres',
#  'lodgers',
#  'British troops',
#  'life',
#  'uniform',
#  'The judges',
#  'authors',
#  'praise',
#  'writing',
#  'preachy prospect',
#  'humane',
#  'eye-popping',
#  'anybody',
#  'the judges',
#  'The first novel section',
#  'the favourite',
#  'creative writing',
#  'course',
#  'fiction',
#  'writer',
#  'buyer',
#  'win',
#  'the first novel category',
#  'unknown author',
#  'this award',
#  'exposure',
#  'a wider',
#  'mass',
#  'audience',
#  'a perfect example',
#  'the influence',
#  'university',
#  'the biography',
#  'category',
#  'winner',
#  'The judges',
#  'readable piece',
#  'scholarship',
#  'the reader',
#  'queens',
#  'many histories',
#  'a fellow',
#  'a honorary research',
#  'professor',
#  'fourth collection',
#  'poems',
#  'the poetry',
#  'award',
#  'works',
#  'mixes',
#  'mysticism',
#  'erotica',
#  'philosophy',
#  'life',
#  'death',
#  'resurrection',
#  'poetry',
#  'documentary films',
#  'winner',
#  'magazine',
#  'publishing',
#  'teaching',
#  'Angels',
#  'the winner',
#  'tale tops',
#  'awards',
#  'book',
#  'fans',
#  'a story',
#  'a boy',
#  'an adventure',
#  'horse',
#  'the winner',
#  'Smarties',
#  'book',
#  'the category',
#  'eight-year-olds',
#  'the award',
#  'after-school club',
#  'members',
#  'a Chinese girl',
#  'a servant',
#  'vote',
#  'readers',
#  'the top award',
#  'the under-five category',
#  'Winners',
#  'children',
#  'a shortlist',
#  'an adult',
#  'panel',
#  'The prize',
#  '20th year',
#  'children',
#  'book',
#  'award',
#  'text',
#  'illustrations',
#  'eights',
#  'after-school club',
#  'members',
#  'chair',
#  'the adult',
#  'judging',
#  'panel',
#  'children',
#  'literature',
#  'the prize',
#  'years',
#  'This award',
#  'the final choice',
#  'winners',
#  'children',
#  'critics',
#  'This year',
#  'young judges',
#  'the winners',
#  'varied shortlist',
#  'children',
#  'books',
#  'today',
#  'Previous winners',
#  'book',
#  'A book',
#  'the evolution',
#  'mutants',
#  'the science',
#  'abnormality',
#  'a lecturer',
#  'the £10,000',
#  'prize',
#  'Mutants',
#  'the form',
#  'varieties',
#  'errors',
#  'the human body',
#  'tradition',
#  'popular science',
#  'today',
#  'judge',
#  'The award',
#  'fiction',
#  'non-fiction',
#  'A panel',
#  'literary experts',
#  'novelists',
#  'director',
#  'the winner',
#  'a five-strong shortlist',
#  'The shortlist',
#  'a novel',
#  'the magic arts',
#  'the turn',
#  'account',
#  'trek',
#  'foot',
#  'book',
#  'the scope',
#  'reference',
#  'elegance',
#  'inquisitiveness',
#  'chair',
#  'the judges',
#  'literary editor',
#  'the subject matter',
#  'the judging',
#  'process',
#  'the overwhelming majority',
#  'words',
#  'director',
#  'work',
#  'provoking',
#  'The award',
#  'first time',
#  'authors',
#  'books',
#  'genres',
#  'fiction',
#  'poetry',
#  'biography',
#  'memoir',
#  'history',
#  'politics',
#  'science',
#  'current affairs',
#  'Previous winners',
#  'a bestseller',
#  'King',
#  'the bestsellers',
#  'the age',
#  'page-turners',
#  'the inner workings',
#  'various industries',
#  'the hotels',
#  'high finance',
#  'the only child',
#  'class',
#  'parents',
#  'school',
#  'the age',
#  'a pilot',
#  'fighter',
#  'planes',
#  'an occupation',
#  'authorial debut',
#  'the television',
#  'screenplay',
#  'a citizen',
#  'a writer',
#  'an early age',
#  'mid-thirties',
#  'first screenplay',
#  'a return',
#  'flight',
#  'the pilots',
#  'the controls',
#  'the airplane',
#  'a rusty wartime',
#  'pilot',
#  'years',
#  '£318',
#  'TV',
#  'comedy',
#  'a screenwriter',
#  'a couple',
#  'years',
#  'novels',
#  'best-selling books',
#  'languages',
#  'countries',
#  'first novel',
#  'a popular following',
#  'The hit',
#  'years',
#  'national best-seller',
#  'lists',
#  'a full year',
#  'a movie',
#  'a glossy soap',
#  'best-loved work',
#  'the disaster',
#  'movie',
#  'genre',
#  'The thriller',
#  'events',
#  'the sky',
#  'the ground',
#  'a snow-logged airport',
#  'a terrorist',
#  'an airplane',
#  'a bomb',
#  'The book',
#  'a hit',
#  'film',
#  'the harassed aiport',
#  'manager',
#  'a womanising',
#  'pilot',
#  'a testament',
#  'the popularity',
#  'the fledgling disaster',
#  'genre',
#  'sequels',
#  'The writer',
#  'research',
#  'the professions',
#  'each novel',
#  'characters',
#  'real life',
#  'years',
#  'each book',
#  'wife',
#  'a lukewarm response',
#  'critics',
#  'few literary accolades',
#  'the height',
#  'fame',
#  'the seventies',
#  'the attention',
#  'producers',
#  'blockbuster',
#  'focusing',
#  'the pharmaceutical industry',
#  'a film',
#  'a panoply',
#  'former soap',
#  'stars',
#  'novel',
#  'final book',
#  'the age',
#  'health',
#  'recent years',
#  'heart',
#  'surgery',
#  'a stroke',
#  'months',
#  'sleep',
#  'dinner',
#  'wife',
#  'children',
#  'home',
#  'island',
#  'a wonderful life',
#  'ambition',
#  'name',
#  'a book',
#  'wife',
#  'world',
#  'list',
#  'British authors',
#  'the shortlist',
#  'the only nominees',
#  'award',
#  'writers',
#  'all nationalities',
#  'The prize',
#  'an author',
#  'body',
#  'work',
#  'book',
#  'the 18-strong list',
#  'world',
#  'literary figures',
#  'other past winners',
#  'the shortlist',
#  'The prize',
#  'years',
#  'an author',
#  'continued creativity',
#  'development',
#  'overall contribution',
#  'fiction',
#  'the world',
#  'stage',
#  'An author',
#  'The international award',
#  'response',
#  'authors',
#  'art',
#  'portfolio',
#  'sale',
#  'The art',
#  'collection',
#  'murdered fashion',
#  'designer',
#  'this year',
#  'the pictures',
#  'sale',
#  'The collection',
#  'townhouse',
#  'The 51-year-old designer',
#  'home',
#  'serial killer',
#  'The auction',
#  'paintings',
#  'the highlights',
#  'the sale',
#  'an estimate',
#  'worldwide head',
#  'contemporary art',
#  'This collection',
#  'wide-ranging taste',
#  'impeccable eye',
#  'the works',
#  'the artists',
#  'examples',
#  'champions',
#  'movement',
#  'masterpieces',
#  'visible artists',
#  'the collaborative genius',
#  'the collection',
#  'sale',
#  'auctions',
#  'contemporary paintings',
#  'the hammer',
#  'A sale',
#  'furniture',
#  ...]

# %%
entities_cust_freq = (word for word in entities_custom_list if word[:1].isupper())
counter_entities_cust = Counter(entities_cust_freq)
print (counter_entities_cust.most_common(10))
# Out:
# [('The film', 24), ('TV', 21), ('This year', 12), ('The awards', 9), ('The actor', 6), ('The sequel', 6), ('The show', 5), ('Oscar', 5), ('The winner', 5), ('The book', 5)]

# %% [markdown]
# ## Extracting information from Wikipedia

# %%
for entity in entities_list:
    try:
        summary = wikipedia.page(wikipedia.search(entity)[0]).summary
    except wikipedia.DisambiguationError:
        pass
    else:
        sent = nltk.sent_tokenize(summary)[0]
        index = sent.index(' is ') if ' is ' in sent else None
        if index is not None:
            cut = sent[index:]
            t_tokens = nltk.word_tokenize(cut)
            t_tagged = nltk.pos_tag(t_tokens)
            t_entities = nltk.ne_chunk(t_tagged, binary=True)
            t_entities_list = []
            for t in t_entities.subtrees():
                if t.label() == 'NE':
                    e_tuples = list(t)
                    s = ''
                    for tup in e_tuples:
                        s += tup[0] + ' '
                    t_entities_list.append(s[:-1])
            if len(t_entities_list) > 0:
                category = t_entities_list[0]
            else:
                category = 'Other'
        else:
                category = 'Other'
        print(entity, ': ', category)
# Out:
# /Users/liutova/anaconda/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /Users/liutova/anaconda/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# London :  England
# Tate Britain :  Millbank
# Tate :  United Kingdom
# Tate :  United Kingdom
# Tracey Emin :  Other
# Norway :  Scandinavian Peninsula
# ArtWorks :  RISC
# Henry Moore :  Other
# Copenhagen :  Denmark
# Denmark :  Scandinavian
# Parken :  Indre Østerbro
# Andersen :  Greek
# Emperor :  Other
# New Clothes :  Danish
# Little Mermaid :  Danish
# Denmark :  Scandinavian
# Crown Princess Mary :  Other
# New York :  United States
# Manhattan :  New York City
# US :  Other
# Harold Bloom :  American
# Andersen :  Greek
# Christian Andersen Award :  Danish
# Odense :  Denmark
# Christian Anderson School :  Anderson
# Ugly Duckling :  Danish
# Helena Christensen :  Danish
# Harvey Keitel :  American
# Sir Roger Moore :  Other
# Cathy Freeman :  Australian
# Jerry Springer :  American
# Frank Capra :  Other
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/liutova/anaconda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383             try:  # Python 2.7, use buffering of HTTP responses
# --> 384                 httplib_response = conn.getresponse(buffering=True)
#     385             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-24a1fad93278> in <module>()
#       1 for entity in entities_list:
#       2     try:
# ----> 3         summary = wikipedia.page(wikipedia.search(entity)[0]).summary
#       4     except wikipedia.DisambiguationError:
#       5         pass
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/wikipedia/wikipedia.py in summary(self)
#     528          query_params['pageids'] = self.pageid
#     529
# --> 530       request = _wiki_request(query_params)
#     531       self._summary = request['query']['pages'][self.pageid]['extract']
#     532
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/wikipedia/wikipedia.py in _wiki_request(params)
#     758     time.sleep(int(wait_time.total_seconds()))
#     759
# --> 760   r = requests.get(API_URL, params=params, headers=headers)
#     761
#     762   if RATE_LIMIT:
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     628
#     629         # Resolve redirects if allowed.
# --> 630         history = [resp for resp in gen] if allow_redirects else []
#     631
#     632         # Shuffle things around if there's history.
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/requests/sessions.py in <listcomp>(.0)
#     628
#     629         # Resolve redirects if allowed.
# --> 630         history = [resp for resp in gen] if allow_redirects else []
#     631
#     632         # Shuffle things around if there's history.
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, **adapter_kwargs)
#     188                 proxies=proxies,
#     189                 allow_redirects=False,
# --> 190                 **adapter_kwargs
#     191             )
#     192
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     592                                                   timeout=timeout_obj,
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#     596             # If we're going to release the connection in ``finally:``, then
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385             except TypeError:  # Python 2.6 and older, Python 3
#     386                 try:
# --> 387                     httplib_response = conn.getresponse()
#     388                 except Exception as e:
#     389                     # Remove the TypeError from the exception chain in Python 3;
#
# /Users/liutova/anaconda/lib/python3.5/http/client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# /Users/liutova/anaconda/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Users/liutova/anaconda/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Users/liutova/anaconda/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     254     def recv_into(self, *args, **kwargs):
#     255         try:
# --> 256             return self.connection.recv_into(*args, **kwargs)
#     257         except OpenSSL.SSL.SysCallError as e:
#     258             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Users/liutova/anaconda/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1332             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1333         else:
# -> 1334             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1335         self._raise_ssl_error(self._ssl, result)
#    1336
#
# KeyboardInterrupt:

# %%
for entity in entities_custom_list:
    try:
        summary = wikipedia.page(wikipedia.search(entity)[0]).summary
    except wikipedia.DisambiguationError:
        pass
    else:
        sent = nltk.sent_tokenize(summary)[0]
        index = sent.index(' is ')
        cut = sent[index:]
        t_tokens = nltk.word_tokenize(cut)
        t_tagged = nltk.pos_tag(t_tokens)
        t_entities = cp.parse(t_tagged)
        t_entities_list = []
        for subtree in t_entities.subtrees():
            if subtree.label() == 'NP':
              t_entities_list.append(' '.join(word for word, tag in subtree.leaves()))
        if len(t_entities_list) > 0:
            category = t_entities_list[0]
        else:
            category = 'Other'
        print(entity, ': ', category)
# Out:
# unveils interactive tree :  a metaphor
# tree :  a perennial plant
# /Users/liutova/anaconda/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file /Users/liutova/anaconda/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# messages :  a discrete unit
# art gallery :  a building
# The spruce :  a tree
# an antenna :  an electrical device
# The messages :  an interpretation
# sculptor :  the branch
# broken plates :  a Greek custom
# light :  electromagnetic radiation
# bulbs :  a short stem
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-0a7f31844505> in <module>()
#       6     else:
#       7         sent = nltk.sent_tokenize(summary)[0]
# ----> 8         index = sent.index(' is ')
#       9         cut = sent[index:]
#      10         t_tokens = nltk.word_tokenize(cut)
#
# ValueError: substring not found
